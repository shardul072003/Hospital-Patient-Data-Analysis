# %% [raw]
# Problem Statement : Hospital Patient Data Analysis
# Context:
# A hospital maintains patient records including admission details, department, diagnosis, doctor, and bill amount. You have two datasets: one with patient info and another with billing details. Some patients have blank bill amounts, and there are multiple rows for the same patient due to follow-ups.
# Tasks:
# 1.	Load the patient dataset and show summary with info().
# 2.	Select only the columns relevant for billing: ['PatientID', 'Department', 'Doctor', 'BillAmount'].
# 3.	Drop administrative columns like ['ReceptionistID', 'CheckInTime'].
# 4.	Use groupby to find total bill amount per department.
# 5.	Remove duplicate patient records based on PatientID.
# 6.	Fill missing BillAmount values with the mean bill amount.
# 7.	Merge the billing dataset with patient dataset on PatientID.
# 8.	Concatenate an additional DataFrame that contains new patients for the current week (row-wise).
# 9.	Concatenate new billing category columns like ['InsuranceCovered', 'FinalAmount'] (column-wise).
# Expected Outcome:
# •	Final cleaned dataset with accurate billing info.
# •	All missing values handled, merged dataset across PatientID.
# •	Ability to perform further analytics on department-wise revenue or doctor performance.

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("Billing_data.csv")

# %%
df2=pd.read_csv("Patient_data.csv")

# %%
df1
# Out:
#    PatientID  InsuranceCovered  FinalAmount
# 0        101              2000         3000
# 1        102              1500         3500
# 2        103              2500         5000
# 3        104              3000         3200
# 4        105              1000         4000

# %%
df2
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  ReceptionistID  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0               1
# 1        102      Bob    Neurology   Dr. John         NaN               2
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0               1
# 3        104    David   Cardiology  Dr. Smith      6200.0               3
# 4        105      Eva  Dermatology   Dr. Rose         NaN               2
# 5        101    Alice   Cardiology  Dr. Smith      5000.0               1
#
#         CheckInTime
# 0  2023-01-10 09:00
# 1  2023-01-11 10:30
# 2  2023-01-12 11:00
# 3  2023-01-13 12:00
# 4  2023-01-14 08:45
# 5  2023-01-10 09:00

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PatientID         5 non-null      int64
#  1   InsuranceCovered  5 non-null      int64
#  2   FinalAmount       5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PatientID       6 non-null      int64
#  1   Name            6 non-null      object
#  2   Department      6 non-null      object
#  3   Doctor          6 non-null      object
#  4   BillAmount      4 non-null      float64
#  5   ReceptionistID  6 non-null      int64
#  6   CheckInTime     6 non-null      object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 468.0+ bytes

# %%
df1.describe()
# Out:
#         PatientID  InsuranceCovered  FinalAmount
# count    5.000000          5.000000     5.000000
# mean   103.000000       2000.000000  3740.000000
# std      1.581139        790.569415   798.749022
# min    101.000000       1000.000000  3000.000000
# 25%    102.000000       1500.000000  3200.000000
# 50%    103.000000       2000.000000  3500.000000
# 75%    104.000000       2500.000000  4000.000000
# max    105.000000       3000.000000  5000.000000

# %%
df2.describe()
# Out:
#         PatientID   BillAmount  ReceptionistID
# count    6.000000     4.000000        6.000000
# mean   102.666667  5925.000000        1.666667
# std      1.632993  1192.686044        0.816497
# min    101.000000  5000.000000        1.000000
# 25%    101.250000  5000.000000        1.000000
# 50%    102.500000  5600.000000        1.500000
# 75%    103.750000  6525.000000        2.000000
# max    105.000000  7500.000000        3.000000

# %%
df1.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df2.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
df2.duplicated().isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df2
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  ReceptionistID  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0               1
# 1        102      Bob    Neurology   Dr. John         NaN               2
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0               1
# 3        104    David   Cardiology  Dr. Smith      6200.0               3
# 4        105      Eva  Dermatology   Dr. Rose         NaN               2
# 5        101    Alice   Cardiology  Dr. Smith      5000.0               1
#
#         CheckInTime
# 0  2023-01-10 09:00
# 1  2023-01-11 10:30
# 2  2023-01-12 11:00
# 3  2023-01-13 12:00
# 4  2023-01-14 08:45
# 5  2023-01-10 09:00

# %%
num = df2.select_dtypes(['int','float'])
num
# Out:
#    PatientID  BillAmount  ReceptionistID
# 0        101      5000.0               1
# 1        102         NaN               2
# 2        103      7500.0               1
# 3        104      6200.0               3
# 4        105         NaN               2
# 5        101      5000.0               1

# %%
cate = df2.select_dtypes(["object"])
cate
# Out:
#       Name   Department     Doctor       CheckInTime
# 0    Alice   Cardiology  Dr. Smith  2023-01-10 09:00
# 1      Bob    Neurology   Dr. John  2023-01-11 10:30
# 2  Charlie  Orthopedics    Dr. Lee  2023-01-12 11:00
# 3    David   Cardiology  Dr. Smith  2023-01-13 12:00
# 4      Eva  Dermatology   Dr. Rose  2023-01-14 08:45
# 5    Alice   Cardiology  Dr. Smith  2023-01-10 09:00

# %%
num.mean()
# Out:
# PatientID          102.666667
# BillAmount        5925.000000
# ReceptionistID       1.666667
# dtype: float64

# %%
df2[["PatientID","Department","Doctor","BillAmount"]]
# Out:
#    PatientID   Department     Doctor  BillAmount
# 0        101   Cardiology  Dr. Smith      5000.0
# 1        102    Neurology   Dr. John         NaN
# 2        103  Orthopedics    Dr. Lee      7500.0
# 3        104   Cardiology  Dr. Smith      6200.0
# 4        105  Dermatology   Dr. Rose         NaN
# 5        101   Cardiology  Dr. Smith      5000.0

# %%
df2.drop('ReceptionistID', axis = 1 , inplace=True)

# %%
df2.drop('CheckInTime' , axis =1 , inplace=True )

# %%
df2
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN
# 5        101    Alice   Cardiology  Dr. Smith      5000.0

# %%
df2['BillAmount'].fillna(df2['BillAmount'].mean() , inplace=True)

# %%
df2
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John      5925.0
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose      5925.0
# 5        101    Alice   Cardiology  Dr. Smith      5000.0

# %%
df2.drop_duplicates(inplace=True)

# %%
df2
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John      5925.0
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose      5925.0

# %%
billing_total=df2.groupby('Department')['BillAmount'].sum().reset_index()
billing_total
# Out:
#     Department  BillAmount
# 0   Cardiology     11200.0
# 1  Dermatology      5925.0
# 2    Neurology      5925.0
# 3  Orthopedics      7500.0

# %%
merging=pd.merge(df1,df2, on='PatientID')

# %%
merging
# Out:
#    PatientID  InsuranceCovered  FinalAmount     Name   Department     Doctor  \
# 0        101              2000         3000    Alice   Cardiology  Dr. Smith
# 1        102              1500         3500      Bob    Neurology   Dr. John
# 2        103              2500         5000  Charlie  Orthopedics    Dr. Lee
# 3        104              3000         3200    David   Cardiology  Dr. Smith
# 4        105              1000         4000      Eva  Dermatology   Dr. Rose
#
#    BillAmount
# 0      5000.0
# 1      5925.0
# 2      7500.0
# 3      6200.0
# 4      5925.0

# %%
new_patients = pd.DataFrame({
    'PatientID': [106, 107],
    'Name': ['John', 'Tony'],
    'Department': ['Cardiology', 'Orthopaedics'],
    'Doctor': ['Dr. Lee', 'Dr. Rose'],
    'BillAmount': [4500.000000, 6200.000000]
})

patient_updated = pd.concat([df2, new_patients], ignore_index=True)
patient_updated
# Out:
#    PatientID     Name    Department     Doctor  BillAmount
# 0        101    Alice    Cardiology  Dr. Smith      5000.0
# 1        102      Bob     Neurology   Dr. John      5925.0
# 2        103  Charlie   Orthopedics    Dr. Lee      7500.0
# 3        104    David    Cardiology  Dr. Smith      6200.0
# 4        105      Eva   Dermatology   Dr. Rose      5925.0
# 5        106     John    Cardiology    Dr. Lee      4500.0
# 6        107     Tony  Orthopaedics   Dr. Rose      6200.0

# %%
final_dataset = pd.merge(patient_updated, df1,on='PatientID',how='left')

# %%
final_dataset['InsuranceCovered'].fillna(0, inplace=True)

# %%
final_dataset['FinalAmount'].fillna(final_dataset['BillAmount'], inplace=True)

# %%
final_dataset
# Out:
#    PatientID     Name    Department     Doctor  BillAmount  InsuranceCovered  \
# 0        101    Alice    Cardiology  Dr. Smith      5000.0            2000.0
# 1        102      Bob     Neurology   Dr. John      5925.0            1500.0
# 2        103  Charlie   Orthopedics    Dr. Lee      7500.0            2500.0
# 3        104    David    Cardiology  Dr. Smith      6200.0            3000.0
# 4        105      Eva   Dermatology   Dr. Rose      5925.0            1000.0
# 5        106     John    Cardiology    Dr. Lee      4500.0               0.0
# 6        107     Tony  Orthopaedics   Dr. Rose      6200.0               0.0
#
#    FinalAmount
# 0       3000.0
# 1       3500.0
# 2       5000.0
# 3       3200.0
# 4       4000.0
# 5       4500.0
# 6       6200.0
